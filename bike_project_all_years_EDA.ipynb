# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fdf_gdf21 = pd.read_csv(r'C:\Users\raclo\Documents\Bootcamp\Project 3\fdf_gdf21.csv', low_memory=False, sep=",")

# %%
fdf_gdf22 = pd.read_csv(r'C:\Users\raclo\Documents\Bootcamp\Project 3\fdf_gdf22.csv', low_memory=False, sep=",")

# %%
fdf_gdf23 = pd.read_csv(r'C:\Users\raclo\Documents\Bootcamp\Project 3\fdf_gdf.csv', low_memory=False, sep=",")

# %%
fdf_gdf21.head()
# Out:
#    Unnamed: 0  ride_id rideable_type           started_at  \
# 0           0  2226895  classic_bike  2021-10-22 22:26:26
# 1           1   183935  classic_bike  2021-03-03 08:28:05
# 2           2  1846205  classic_bike  2021-09-17 14:29:27
# 3           3  2261617  classic_bike  2021-10-26 12:30:15
# 4           4  2193498  classic_bike  2021-10-20 07:25:39
#
#               ended_at                         start_station_name  \
# 0  2021-10-22 22:33:05                             11th & M St NW
# 1  2021-03-03 08:30:38                        11th & Girard St NW
# 2  2021-09-17 14:41:37                              1st & M St SE
# 3  2021-10-26 12:33:48  Lincoln Park / 13th & East Capitol St NE
# 4  2021-10-20 07:33:46             California St & Florida Ave NW
#
#    start_station_id                              end_station_name  \
# 0           31266.0                                11th & O St NW
# 1           31126.0                         10th & Florida Ave NW
# ...

# %%
fdf_gdf21 = fdf_gdf21.drop(['Unnamed: 0'], axis=1)
print(fdf_gdf21)
# Out:
#         ride_id rideable_type           started_at             ended_at  \
# 0       2226895  classic_bike  2021-10-22 22:26:26  2021-10-22 22:33:05
# 1        183935  classic_bike  2021-03-03 08:28:05  2021-03-03 08:30:38
# 2       1846205  classic_bike  2021-09-17 14:29:27  2021-09-17 14:41:37
# 3       2261617  classic_bike  2021-10-26 12:30:15  2021-10-26 12:33:48
# 4       2193498  classic_bike  2021-10-20 07:25:39  2021-10-20 07:33:46
# ...         ...           ...                  ...                  ...
# 513653  2296973  classic_bike  2021-10-30 11:55:33  2021-10-30 12:09:54
# 513654  2612249  classic_bike  2021-12-07 15:58:37  2021-12-07 16:01:26
# 513655  2666790   docked_bike  2021-12-15 12:20:53  2021-12-15 12:43:42
# 513656  2229214  classic_bike  2021-10-23 09:57:38  2021-10-23 10:09:46
# 513657  2146391  classic_bike  2021-10-15 15:15:11  2021-10-15 15:55:52
#
#                                  start_station_name  start_station_id  \
# ...

# %%
fdf_gdf22.head()
# Out:
#    Unnamed: 0  ride_id  rideable_type           started_at  \
# 0           1  3099712   classic_bike  2022-03-13 12:44:09
# 1           2  2777507   classic_bike  2022-01-10 21:29:14
# 2           3  5150685    docked_bike  2022-09-07 16:11:54
# 3           4  6012859   classic_bike  2022-11-24 21:11:02
# 4           5  3630578  electric_bike  2022-05-05 20:08:53
#
#               ended_at                                 start_station_name  \
# 0  2022-03-13 12:49:45  Woodley Park Metro / Calvert St & Connecticut ...
# 1  2022-01-10 21:34:09                                      4th & E St SW
# 2  2022-09-07 16:27:23                              Maine Ave & 7th St SW
# 3  2022-11-24 21:39:54                  Convention Center / 7th & M St NW
# 4  2022-05-05 20:11:22                                      1st & O St NW
#
#    start_station_id          end_station_name  end_station_id  start_lat  ...  \
# 0           31323.0  18th St & Wyoming Ave NW         31114.0  38.923389  ...
# ...

# %%
fdf_gdf22 = fdf_gdf22.drop(['Unnamed: 0'], axis=1)
print(fdf_gdf22)
# Out:
#         ride_id  rideable_type           started_at             ended_at  \
# 0       3099712   classic_bike  2022-03-13 12:44:09  2022-03-13 12:49:45
# 1       2777507   classic_bike  2022-01-10 21:29:14  2022-01-10 21:34:09
# 2       5150685    docked_bike  2022-09-07 16:11:54  2022-09-07 16:27:23
# 3       6012859   classic_bike  2022-11-24 21:11:02  2022-11-24 21:39:54
# 4       3630578  electric_bike  2022-05-05 20:08:53  2022-05-05 20:11:22
# ...         ...            ...                  ...                  ...
# 687739  5609931   classic_bike  2022-10-15 18:06:45  2022-10-15 18:58:33
# 687740  5379535   classic_bike  2022-09-24 15:43:12  2022-09-24 15:50:21
# 687741  4182078  electric_bike  2022-06-21 19:05:35  2022-06-21 19:10:03
# 687742  5348797  electric_bike  2022-09-22 11:10:32  2022-09-22 11:12:25
# 687743  2857050   classic_bike  2022-01-31 14:01:20  2022-01-31 14:09:54
#
#                                        start_station_name  start_station_id  \
# ...

# %%
fdf_gdf23.head()
# Out:
#     ride_id  rideable_type          started_at            ended_at  \
# 0   7368109  electric_bike 2023-05-05 10:57:59 2023-05-05 11:21:16
# 1   6480084   classic_bike 2023-02-08 17:29:29 2023-02-08 17:52:32
# 2   6546649   classic_bike 2023-02-17 10:40:44 2023-02-17 10:52:14
# 3   8494852   classic_bike 2023-07-21 21:31:20 2023-07-21 21:38:29
# 4  10613115  electric_bike 2023-12-19 17:34:05 2023-12-19 17:39:06
#
#                start_station_name  start_station_id  \
# 0                               0               0.0
# 1              Hamlin & 7th St NE           31514.0
# 2          Eckington Pl & Q St NE           31505.0
# 3  New Hampshire Ave & Ward Pl NW           31212.0
# 4            14th & Belmont St NW           31119.0
#
#                 end_station_name  end_station_id  start_lat  start_lng  ...  \
# 0  17th St & Rhode Island Ave NW         31210.0  38.880000 -77.010000  ...
# 1    Adams Mill & Columbia Rd NW         31104.0  38.927497 -76.997194  ...
# ...

# %%
fdf_gdf21.dtypes
# Out:
# ride_id                 int64
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id      float64
# end_station_name       object
# end_station_id        float64
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# distance              float64
# month                   int64
# year                    int64
# season                 object
# day_of_week            object
# holiday                object
# is_weekend             object
# ride_duration          object
# start_ward              int64
# end_ward                int64
# ride_duration_min     float64
# dtype: object

# %%
fdf_gdf22.dtypes
# Out:
# ride_id                 int64
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id      float64
# end_station_name       object
# end_station_id        float64
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# distance              float64
# month                   int64
# year                    int64
# season                 object
# day_of_week            object
# holiday                object
# is_weekend             object
# ride_duration          object
# start_ward              int64
# end_ward                int64
# ride_duration_min     float64
# geometry               object
# longitude             float64
# latitude              float64
# dtype: object

# %%
fdf_gdf23.dtypes
# Out:
# ride_id                 int64
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id      float64
# end_station_name       object
# end_station_id        float64
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# distance              float64
# month                   int64
# year                    int64
# season                 object
# day_of_week            object
# holiday                object
# is_weekend             object
# ride_duration          object
# start_ward              int64
# end_ward                int64
# ride_duration_min     float64
# dtype: object

# %%
# Convert categorical columns to category type for memory efficiency
fdf_gdf21["rideable_type"] = fdf_gdf21["rideable_type"].astype("category")
fdf_gdf21["start_station_name"] = fdf_gdf21["start_station_name"].astype("category")
fdf_gdf21["end_station_name"] = fdf_gdf21["end_station_name"].astype("category")
fdf_gdf21["member_casual"] = fdf_gdf21["member_casual"].astype("category")
fdf_gdf21["day_of_week"] = fdf_gdf21["day_of_week"].astype("category")
fdf_gdf21["holiday"] = fdf_gdf21["holiday"].astype("category")

fdf_gdf21["is_weekend"] = fdf_gdf21["is_weekend"].astype("category")

# Convert started_at and ended_at to datetime for memory efficiency
fdf_gdf21['started_at'] = pd.to_datetime(fdf_gdf21['started_at'])
fdf_gdf21['ended_at'] = pd.to_datetime(fdf_gdf21['ended_at'])


fdf_gdf21['month'] = fdf_gdf21['month'].astype('int8')
fdf_gdf21["year"] = fdf_gdf21["year"].astype("str")

fdf_gdf21["ride_duration"] = pd.to_timedelta(fdf_gdf21["ride_duration"])

# %%
# Convert categorical columns to category type for memory efficiency
fdf_gdf22["rideable_type"] = fdf_gdf22["rideable_type"].astype("category")
fdf_gdf22["start_station_name"] = fdf_gdf22["start_station_name"].astype("category")
fdf_gdf22["end_station_name"] = fdf_gdf22["end_station_name"].astype("category")
fdf_gdf22["member_casual"] = fdf_gdf22["member_casual"].astype("category")
fdf_gdf22["day_of_week"] = fdf_gdf22["day_of_week"].astype("category")
fdf_gdf22["holiday"] = fdf_gdf22["holiday"].astype("category")

fdf_gdf22["holiday"] = fdf_gdf22["holiday"].astype("category")

# Convert started_at and ended_at to datetime for memory efficiency
fdf_gdf22['started_at'] = pd.to_datetime(fdf_gdf22['started_at'])
fdf_gdf22['ended_at'] = pd.to_datetime(fdf_gdf22['ended_at'])


fdf_gdf22['month'] = fdf_gdf22['month'].astype('int8')
fdf_gdf22["year"] = fdf_gdf22["year"].astype("str")

fdf_gdf22["ride_duration"] = pd.to_timedelta(fdf_gdf22["ride_duration"])

# %%
# Convert categorical columns to category type for memory efficiency
fdf_gdf23["rideable_type"] = fdf_gdf23["rideable_type"].astype("category")
fdf_gdf23["start_station_name"] = fdf_gdf23["start_station_name"].astype("category")
fdf_gdf23["end_station_name"] = fdf_gdf23["end_station_name"].astype("category")
fdf_gdf23["member_casual"] = fdf_gdf23["member_casual"].astype("category")
fdf_gdf23["day_of_week"] = fdf_gdf23["day_of_week"].astype("category")
fdf_gdf23["holiday"] = fdf_gdf23["holiday"].astype("category")

# Convert started_at and ended_at to datetime for memory efficiency
fdf_gdf23['started_at'] = pd.to_datetime(fdf_gdf23['started_at'])
fdf_gdf23['ended_at'] = pd.to_datetime(fdf_gdf23['ended_at'])

fdf_gdf23["holiday"] = fdf_gdf23["holiday"].astype("category")

fdf_gdf23['month'] = fdf_gdf23['month'].astype('int8')
fdf_gdf23["year"] = fdf_gdf23["year"].astype("str")

fdf_gdf23["ride_duration"] = pd.to_timedelta(fdf_gdf23["ride_duration"])

# %%
# Extract unique stations by start ward for each year
unique_stations_2021 = fdf_gdf21.groupby('start_ward')['start_station_name'].nunique().reset_index()
unique_stations_2021['year'] = 2021

unique_stations_2022 = fdf_gdf22.groupby('start_ward')['start_station_name'].nunique().reset_index()
unique_stations_2022['year'] = 2022

unique_stations_2023 = fdf_gdf23.groupby('start_ward')['start_station_name'].nunique().reset_index()
unique_stations_2023['year'] = 2023

# Combine the dataframes
unique_stations = pd.concat([unique_stations_2021, unique_stations_2022, unique_stations_2023])

# Rename columns for clarity
unique_stations.columns = ['start_ward', 'unique_stations', 'year']

# Plot the density
# Create bar plots for each year and each Ward
plt.figure(figsize=(15, 10))
sns.barplot(data=unique_stations, x='start_ward', y='unique_stations', hue='year', palette='viridis')
plt.title('Number of Unique Stations by Start Ward and Year (2021-2023)')
plt.xlabel('Start Ward')
plt.ylabel('Number of Unique Stations')
plt.legend(title='Year')
plt.show()

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point# Load the wards GeoJSON file
wards_gdf = gpd.read_file("wards_from_2022.geojson")

# %%
wards_gdf
# Out:
#    WARD    NAME              REP_NAME  \
# 0     8  Ward 8     Trayon White, Sr.
# 1     6  Ward 6         Charles Allen
# 2     7  Ward 7        Wendell Felder
# 3     2  Ward 2          Brooke Pinto
# 4     1  Ward 1        Brianne Nadeau
# 5     5  Ward 5        Zachary Parker
# 6     3  Ward 3        Matthew Frumin
# 7     4  Ward 4  Janeese Lewis George
#
#                                              WEB_URL       REP_PHONE  \
# 0  https://www.dccouncil.us/council/councilmember...  (202) 724-8045
# 1  https://www.dccouncil.us/council/councilmember...  (202) 724-8072
# 2          https://dccouncil.us/council/vincent-gray  (202) 724-8068
# 3  https://www.dccouncil.us/council/ward-2-counci...  (202) 724-8058
# 4        https://dccouncil.us/council/brianne-nadeau  (202) 724-8181
# 5       https://dccouncil.us/council/kenyan-mcduffie  (202) 724-8028
# 6  https://www.dccouncil.us/council/council-membe...  (202) 724-8062
# ...

# %%
# Ensure the GeoDataFrame has a proper coordinate reference system (CRS) for area calculation
wards_gdf = wards_gdf.to_crs(epsg=3395)  # Use a projected CRS suitable for area calculation

# Calculate the area in square meters and convert to square kilometers
wards_gdf['area_km2'] = wards_gdf['geometry'].area / 1e6

# Reset the CRS back to the original for further operations
wards_gdf = wards_gdf.to_crs(epsg=4326)

print(wards_gdf[['WARD', 'area_km2']])
# Out:
#    WARD   area_km2
# 0     8  53.199005
# 1     6  28.996839
# 2     7  39.505974
# 3     2  30.231973
# 4     1  10.831974
# 5     5  44.380534
# 6     3  46.686393
# 7     4  38.462563

# %%
# Merge unique_stations with ward areas
unique_stations_with_area = unique_stations.merge(wards_gdf[['WARD', 'area_km2']], left_on='start_ward', right_on='WARD')

# Calculate density
unique_stations_with_area['density'] = unique_stations_with_area['unique_stations'] / unique_stations_with_area['area_km2']

# Display the result
print(unique_stations_with_area[['start_ward', 'year', 'density']])
# Out:
#     start_ward  year   density
# 0            1  2021  3.600452
# 1            2  2021  3.440067
# 2            3  2021  0.578327
# 3            4  2021  0.597984
# 4            5  2021  0.878764
# 5            6  2021  2.310597
# 6            7  2021  0.708754
# 7            8  2021  0.639110
# 8            1  2022  4.339006
# 9            2  2022  3.506222
# 10           3  2022  0.599746
# 11           4  2022  0.649983
# 12           5  2022  1.013958
# 13           6  2022  2.586489
# 14           7  2022  0.835317
# 15           8  2022  0.657907
# 16           1  2023  8.216415
# 17           2  2023  5.193177
# 18           3  2023  0.878200
# 19           4  2023  1.897949
# 20           5  2023  1.644865
# 21           6  2023  3.483138
# 22           7  2023  0.987192
# 23           8  2023  0.827083

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set figure size & style
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

# Create barplot with better colors
sns.barplot(
    data=unique_stations_with_area, 
    x='start_ward', 
    y='density', 
    hue='year', 
    palette="Blues",  # Try 'magma', 'crest', or 'Set2' for variety
    edgecolor='black',  # Clearer bar edges
    dodge=True  # Ensures hue separation
)


# Title & labels
plt.title('Density of Unique Stations by Ward and Year (2021-2023)', fontsize=16, fontweight='bold')
plt.xlabel('Ward', fontsize=14)
plt.ylabel('Density (Unique Stations per km²)', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Improve legend
plt.legend(title='Year', title_fontsize=13, fontsize=12, loc="upper right")

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set figure size & style
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

# Create barplot with better colors
ax = sns.barplot(
    data=unique_stations_with_area, 
    x='start_ward', 
    y='density', 
    hue='year', 
    palette="Blues",  # Try 'magma', 'crest', or 'Set2' for variety
    edgecolor='black',  # Clearer bar edges
    dodge=True  # Ensures hue separation
)

# Add labels on top of each bar
for bars in ax.containers:
    ax.bar_label(bars, fmt="%.2f", fontsize=12, padding=3, color="black")

# Title & labels
plt.title('Density of Unique Stations by Ward and Year (2021-2023)', fontsize=16, fontweight='bold')
plt.xlabel('Ward', fontsize=14)
plt.ylabel('Density (Unique Stations per km²)', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Improve legend
plt.legend(title='Year', title_fontsize=13, fontsize=12, loc="upper right")

# Show the plot
plt.show()

# %%
# Combine the dataframes for all years
combined_df = pd.concat([fdf_gdf21, fdf_gdf22, fdf_gdf23])

# Melt the dataframe to consider both start_ward and end_ward
melted_df = pd.melt(combined_df, id_vars=['ride_id', 'year'], value_vars=['start_ward', 'end_ward'], 
                    var_name='ward_type', value_name='ward')

# Group by ward and year, and count the number of rides
rides_by_ward_year = melted_df.groupby(['ward', 'year']).size().reset_index(name='ride_count')

# Calculate the total rides per year
total_rides_per_year = rides_by_ward_year.groupby('year')['ride_count'].transform('sum')

# Calculate the share of rides
rides_by_ward_year['ride_share'] = (rides_by_ward_year['ride_count'] / total_rides_per_year) * 100

# Display the result
print(rides_by_ward_year)
# Out:
#     ward  year  ride_count  ride_share
# 0      1  2021      148285   14.434215
# 1      1  2022      195339   14.201433
# 2      1  2023      251600   14.980060
# 3      2  2021      463571   45.124480
# 4      2  2022      624728   45.418644
# 5      2  2023      723876   43.098991
# 6      3  2021       29122    2.834766
# 7      3  2022       31973    2.324484
# 8      3  2023       42941    2.556672
# 9      4  2021       20109    1.957431
# 10     4  2022       24037    1.747525
# 11     4  2023       38398    2.286186
# 12     5  2021       61121    5.949581
# 13     5  2022       90509    6.580137
# 14     5  2023      122375    7.286108
# 15     6  2021      265066   25.801798
# 16     6  2022      360799   26.230618
# 17     6  2023      444363   26.457013
# 18     7  2021       15855    1.543342
# 19     7  2022       18759    1.363807
# 20     7  2023       22424    1.335107
# 21     8  2021       24187    2.354388
# 22     8  2022       29344    2.133352
# ...

# %%
# Set figure size and style
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

# Create barplot for ride share
sns.barplot(
    data=rides_by_ward_year, 
    x='ward', 
    y='ride_share', 
    hue='year', 
    palette="Blues",  # Color palette for better visualization
    edgecolor='black',   # Softer look
    width=0.8,        # Clearer bar edges# Clearer bar edges
    dodge=True  # Ensures hue separation         # Ensures hue separation
)

# Title and labels
plt.title('Share of Rides per Ward and Year (2021-2023)', fontsize=16, fontweight='bold')
plt.xlabel('Ward', fontsize=14)
plt.ylabel('Ride Share (%)', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Improve legend
plt.legend(title='Year', title_fontsize=13, fontsize=12, loc="upper right")

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set figure size & style
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

# Create the barplot
ax = sns.barplot(
    data=rides_by_ward_year, 
    x='ward', 
    y='ride_share', 
    hue='year', 
    palette="Blues",  # Adjust colors as needed
    edgecolor='black',  
    width=0.8,         
    dodge=True
)

# Add labels on bars with 1 decimal place
for container in ax.containers:
    ax.bar_label(container, fmt='%.1f', fontsize=12, padding=3)  # Format to 1 decimal place

# Title and labels
plt.title('Share of Rides per Ward and Year (2021-2023)', fontsize=16, fontweight='bold')
plt.xlabel('Ward', fontsize=14)
plt.ylabel('Ride Share (%)', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Improve legend
plt.legend(title='Year', title_fontsize=13, fontsize=12, loc="upper right")

# Show the plot
plt.show()
